# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Polygon

# %%
path = "/Users/Caroline/Documents/CS/AEData.xlsx"

#import each sheet from excel into its own dataframe
df0 = pd.read_excel(path,sheet_name=0,header=0)
df1 = pd.read_excel(path,sheet_name=1,header=0)
df2 = pd.read_excel(path,sheet_name=2,header=0)
df3 = pd.read_excel(path,sheet_name=3,header=0)

df_merged = pd.read_excel(path,sheet_name=4,header=0)

#head function shows top rows of dataframe
#tail function can be used to see the bottom
#you can also specify how many rows you want to see in the parathensis
df_merged
# Out:
#      Identity      LNAME      FNAME Gender OPT    CS       Obj      Spat  \
# 0      7102.4     SOMMER     RACHEL      F   C  True  3.466667  3.466667
# 1      7103.1  SHARKSNAS  ALEXANDER      M   C  True  3.800000  3.600000
# 2      7103.2       WANG      HUIYU      M   C  True  4.133333  3.866667
# 3      7103.3     ERRICO   NICHOLAS      M   C  True  3.000000  3.400000
# 4      7104.1     JACOBY     NATHAN      M   C  True  3.333333  3.733333
# ..        ...        ...        ...    ...  ..   ...       ...       ...
# 258   11109.3       Bell    Kristen      F   S  True  3.133333  3.533333
# 259  111015.3  Shatynski       Paul      M   S  True  2.533333  3.933333
# 260  111016.2    Jantzen      Tyler      M   S  True  3.533333  3.333333
# 261  111017.1       Smth      Tyler      M   S  True  3.600000  3.800000
# 262  111017.4        Lee      Dylan      M   S  True  2.733333  4.000000
#
#          Verb
# 0    3.466667
# 1    3.200000
# 2    3.600000
# 3    3.066667
# ...

# %%
#fake sample data from documentation example
#https://matplotlib.org/3.1.1/gallery/statistics/boxplot_demo.html

# Fixing random state for reproducibility
np.random.seed(19680801)

# fake up some data
spread = np.random.rand(50) * 100
center = np.ones(25) * 50
flier_high = np.random.rand(10) * 100 + 100
flier_low = np.random.rand(10) * -100
data = np.concatenate((spread, center, flier_high, flier_low))

#type the variable name in the. last line of the cell to print/show values
#I commented it out here just to save space
#data

# %%
L13_data_0 = df0[(df0['OPT'] == 'L')]

L13_verb = L13_data_0['Verb']

L13_obj = L13_data_0['Obj']

L13_spat = L13_data_0['Spat']

S13_data_0 = df0[(df0['OPT'] == 'S')]

S13_obj = S13_data_0['Obj']

S13_spat = S13_data_0['Spat']

S13_verb = S13_data_0['Verb']

C13_data_0 = df0[(df0['OPT'] == 'C')]

C13_obj = C13_data_0['Obj']

C13_spat = C13_data_0['Spat']

C13_verb = C13_data_0['Verb']

M13_data_0 = df0[(df0['OPT'] == 'M')]

M13_obj = M13_data_0['Obj']

M13_spat = M13_data_0['Spat']

M13_verb = M13_data_0['Verb']

M13_verb, M13_obj, M13_spat,C13_verb,C13_spat,C13_obj,S13_verb,S13_spat,S13_obj,L13_verb, L13_spat, L13_obj
# Out:
# (5     3.533333
#  15    3.000000
#  18    2.733333
#  19    2.933333
#  21    3.200000
#  26    3.866667
#  30    3.533333
#  36    2.066667
#  40    2.533333
#  52    2.733333
#  55    2.200000
#  58    2.733333
#  62    2.266667
#  64    2.666667
#  65    2.666667
#  Name: Verb, dtype: float64, 5     3.533333
#  15    3.600000
#  18    3.266667
#  19    3.800000
#  21    2.533333
#  26    3.733333
#  30    3.866667
#  36    3.733333
#  40    3.200000
#  52    2.800000
#  55    3.533333
#  58    3.333333
#  62    2.866667
#  64    3.733333
#  65    4.400000
#  Name: Obj, dtype: float64, 5     3.933333
#  15    3.666667
#  18    4.066667
#  19    4.000000
#  21    2.866667
#  26    3.333333
#  30    4.133333
#  36    3.600000
#  40    4.000000
#  52    3.266667
#  55    3.600000
#  58    3.333333
#  62    3.600000
#  64    4.000000
#  65    3.933333
#  Name: Spat, dtype: float64, 6     3.466667
#  7     3.200000
#  8     3.600000
#  9     3.066667
#  11    2.933333
# ...

# %%
# be care when copy and pasting code from online. 
#The "\" symbol after figure is interpretted differently between python, Jupyter, and Chrome

#from pylab import plot, show, savefig, xlim, figure, \
#                 ylim, legend, boxplot, setp, axes

# %%
#here is how the cell above should look
from pylab import plot, show, savefig, xlim, figure,ylim, legend, boxplot, setp, axes

# %%
L14_data_1 = df1[(df1['OPT'] == 'L')]

L14_verb = L14_data_1['Verb']

L14_obj = L14_data_1['Obj']

L14_spat = L14_data_1['Spat']

M14_data_1 = df1[(df1['OPT'] == 'M')]

M14_obj = M14_data_1['Obj']

M14_spat = M14_data_1['Spat']

M14_verb = M14_data_1['Verb']

C14_data_1 = df1[(df1['OPT'] == 'C')]

C14_verb = C14_data_1['Verb']

C14_obj = C14_data_1['Obj']

C14_spat = C14_data_1['Spat']

S14_data_1 = df1[(df1['OPT'] == 'S')]

S14_obj = S14_data_1['Obj']

S14_spat = S14_data_1['Spat']

S14_verb = S14_data_1['Verb']

C14_verb, C14_spat, C14_obj, S14_verb, S14_obj, S14_spat,L14_verb, L14_spat, L14_obj, M14_verb, M14_obj, M14_spat,
# Out:
# (4     2.800000
#  5     1.533333
#  6     2.800000
#  7     2.066667
#  8     2.933333
#  11    2.733333
#  12    3.000000
#  13    2.933333
#  14    3.600000
#  16    1.866667
#  18    3.800000
#  24    2.600000
#  29    3.200000
#  30    2.600000
#  34    2.733333
#  38    2.933333
#  41    2.733333
#  42    2.733333
#  44    3.533333
#  45    3.466667
#  46    3.266667
#  49    3.333333
#  50    2.200000
#  56    3.066667
#  60    2.600000
#  61    3.800000
#  62    2.733333
#  64    3.133333
#  67    2.266667
#  74    2.533333
#  77    2.400000
#  82    2.666667
#  85    1.800000
#  Name: Verb, dtype: float64, 4     4.066667
#  5     4.266667
#  6     3.333333
#  7     4.533333
#  8     3.933333
#  11    3.000000
#  12    4.000000
#  13    3.733333
#  14    3.800000
#  16    4.400000
#  18    3.666667
#  24    4.200000
#  29    3.800000
#  30    4.133333
#  34    3.600000
#  38    3.400000
#  41    4.000000
#  42    3.466667
#  44    3.733333
#  45    3.466667
#  46    3.733333
# ...

# %%
L15_data_2 = df2[(df2['OPT'] == 'L')]

L15_verb = L15_data_2['Verb']

L15_obj = L15_data_2['Obj']

L15_spat = L15_data_2['Spat']

M15_data_2 = df2[(df2['OPT'] == 'M')]

M15_obj = M15_data_2['Obj']

M15_spat = M15_data_2['Spat']

M15_verb = M15_data_2['Verb']

C15_data_2 = df2[(df2['OPT'] == 'C')]

C15_verb = C15_data_2['Verb']

C15_obj = C15_data_2['Obj']

C15_spat = C15_data_2['Spat']

S15_data_2 = df2[(df2['OPT'] == 'S')]

S15_obj = S15_data_2['Obj']

S15_spat = S15_data_2['Spat']

S15_verb = S15_data_2['Verb']

C15_verb, C15_spat, C15_obj, S15_verb, S15_obj, S15_spat,L15_verb, L15_spat, L15_obj, M15_verb, M15_obj, M15_spat,
# Out:
# (2     3.066667
#  3     3.133333
#  4     3.133333
#  6     3.333333
#  14    3.066667
#  17    3.133333
#  19    2.266667
#  20    2.333333
#  27    3.200000
#  28    3.133333
#  29    2.600000
#  30    3.666667
#  33    1.933333
#  34    3.133333
#  36    3.200000
#  40    2.733333
#  42    3.133333
#  50    2.600000
#  51    3.066667
#  52    2.866667
#  54    2.800000
#  59    3.266667
#  62    3.133333
#  70    2.266667
#  73    2.600000
#  74    2.933333
#  75    2.333333
#  78    3.133333
#  79    2.266667
#  80    2.533333
#  82    3.000000
#  Name: Verb, dtype: float64, 2     3.933333
#  3     3.533333
#  4     2.733333
#  6     3.933333
#  14    4.000000
#  17    4.000000
#  19    3.533333
#  20    4.400000
#  27    3.466667
#  28    3.933333
#  29    3.733333
#  30    4.000000
#  33    3.933333
#  34    3.266667
#  36    3.866667
#  40    4.000000
#  42    3.733333
#  50    3.466667
#  51    4.000000
#  52    3.800000
#  54    4.200000
#  59    3.533333
#  62    3.333333
# ...

# %%
L17_data_3 = df3[(df3['OPT'] == 'L')]

L17_verb = L17_data_3['Verb']

L17_obj = L17_data_3['Obj']

L17_spat = L17_data_3['Spat']

M17_data_3 = df3[(df3['OPT'] == 'M')]

M17_obj = M17_data_3['Obj']

M17_spat = M17_data_3['Spat']

M17_verb = M17_data_3['Verb']

C17_data_3 = df3[(df3['OPT'] == 'C')]

C17_verb = C17_data_3['Verb']

C17_obj = C17_data_3['Obj']

C17_spat = C17_data_3['Spat']

S17_data_3 = df3[(df3['OPT'] == 'S')]

S17_obj = S17_data_3['Obj']

S17_spat = S17_data_3['Spat']

S17_verb = S17_data_3['Verb']

C17_verb, C17_spat, C17_obj, S17_verb, S17_obj, S17_spat,L17_verb, L17_spat, L17_obj, M17_verb, M17_obj, M17_spat,
# Out:
# (0     3.533333
#  10    3.066667
#  12    2.133333
#  14    2.933333
#  15    3.066667
#  16    2.666667
#  17    3.066667
#  18    2.800000
#  22    2.533333
#  26    2.600000
#  28    2.733333
#  29    4.000000
#  32    3.066667
#  37    3.466667
#  39    2.600000
#  41    3.066667
#  42    2.933333
#  43    3.400000
#  55    2.933333
#  Name: Verb, dtype: float64, 0     3.666667
#  10    3.533333
#  12    3.933333
#  14    3.266667
#  15    4.000000
#  16    3.933333
#  17    3.266667
#  18    3.000000
#  22    3.533333
#  26    3.333333
#  28    2.533333
#  29    3.066667
#  32    3.333333
#  37    3.866667
#  39    3.266667
#  41    3.333333
#  42    3.866667
#  43    3.733333
#  55    3.266667
#  Name: Spat, dtype: float64, 0     3.800000
#  10    3.800000
#  12    4.133333
#  14    3.400000
#  15    3.466667
#  16    4.000000
#  17    3.266667
#  18    3.466667
#  22    3.800000
#  26    2.933333
#  28    2.000000
#  29    2.933333
#  32    3.000000
#  37    4.000000
# ...

# %%
box_plot_data=[L17_obj,L17_spat,L17_verb]
plt.boxplot(box_plot_data,notch='True',labels=['Obj','Spat','Verb'])

plt.title('Lighting 2017')
plt.ylim(1.5,5)
plt.show()     

box_plot_data=[C17_obj,C17_spat,C17_verb]
plt.boxplot(box_plot_data,notch='True',labels=['Obj','Spat','Verb'])

plt.title('Construction 2017')
plt.ylim(1.5,5)
plt.show() 

box_plot_data=[S17_obj,S17_spat,S17_verb]
plt.boxplot(box_plot_data,notch='True',labels=['Obj','Spat','Verb'])

plt.title('Structural 2017')
plt.ylim(1.5,5)
plt.show()     

box_plot_data=[M17_obj,M17_spat,M17_verb]
plt.boxplot(box_plot_data,notch='True',labels=['Obj','Spat','Verb'])

plt.title('Mechanical 2017')
plt.ylim(1.5,5)
plt.show()

# %%
box_plot_data=[L17_verb,C17_verb,S17_verb,M17_verb]


plt.boxplot(box_plot_data,notch='True',labels=['Lighting','Construction', 'Structural', 'Mechanical'])

plt.title('Verbal 2017')
plt.ylim(1.5,5)

plt.show() 

box_plot_data=[L17_spat,C17_spat,S17_spat,M17_spat]


plt.boxplot(box_plot_data,notch='True',labels=['Lighting','Construction', 'Structural', 'Mechanical'])

plt.title('Spatial 2017')
plt.ylim(1.5,5)

plt.show() 

box_plot_data=[L17_obj,C17_obj,S17_obj,M17_obj]


plt.boxplot(box_plot_data,notch='True',labels=['Lighting','Construction', 'Structural', 'Mechanical'])

plt.title('Object 2017')
plt.ylim(1.5,5)

plt.show()

# %%
L_data = df_merged[(df_merged['OPT'] == 'L')]

L_verb = L_data['Verb']

L_obj = L_data['Obj']

L_spat = L_data['Spat']

M_data = df_merged[(df_merged['OPT'] == 'M')]

M_obj = M_data['Obj']

M_spat = M_data['Spat']

M_verb = M_data['Verb']

C_data = df_merged[(df_merged['OPT'] == 'C')]

C_verb = C_data['Verb']

C_obj = C_data['Obj']

C_spat = C_data['Spat']

S_data = df_merged[(df_merged['OPT'] == 'S')]

S_obj = S_data['Obj']

S_spat = S_data['Spat']

S_verb = S_data['Verb']


L_verb, L_spat, L_obj,S_verb, S_spat, S_obj,C_verb, C_spat, C_obj, M_verb, M_spat, M_obj
# Out:
# (92     3.200000
#  93     3.066667
#  94     3.733333
#  95     3.333333
#  96     3.266667
#  97     2.333333
#  98     2.733333
#  99     2.933333
#  100    3.333333
#  101    2.266667
#  102    1.800000
#  103    2.866667
#  104    2.466667
#  105    3.000000
#  106    3.066667
#  107    3.266667
#  108    2.866667
#  109    2.666667
#  110    2.733333
#  111    2.933333
#  112    2.266667
#  113    3.066667
#  114    2.800000
#  115    3.800000
#  116    1.866667
#  117    3.533333
#  118    1.933333
#  119    2.266667
#  120    3.333333
#  121    2.666667
#  122    2.600000
#  123    2.466667
#  124    3.333333
#  125    2.800000
#  126    2.666667
#  127    3.400000
#  128    2.066667
#  129    2.466667
#  130    3.333333
#  131    2.866667
#  132    3.066667
#  133    3.400000
#  134    3.200000
#  135    2.600000
#  136    2.200000
#  137    2.600000
#  138    2.600000
#  139    3.133333
#  140    2.866667
#  141    2.800000
#  142    2.666667
#  143    2.666667
# ...

# %%
box_plot_data=[L_verb,C_verb,S_verb,M_verb]


plt.boxplot(box_plot_data,notch='True',labels=['Lighting','Construction', 'Structural', 'Mechanical'])

plt.title('Verbal')
plt.ylim(1.5,5)

plt.show() 

box_plot_data=[L_spat,C_spat,S_spat,M_spat]


plt.boxplot(box_plot_data,notch='True',labels=['Lighting','Construction', 'Structural', 'Mechanical'])

plt.title('Spatial')
plt.ylim(1.5,5)

plt.show() 

box_plot_data=[L_obj,C_obj,S_obj,M_obj]


plt.boxplot(box_plot_data,notch='True',labels=['Lighting','Construction', 'Structural', 'Mechanical'])

plt.title('Object')
plt.ylim(1.5,5)

plt.show()

# %%
box_plot_data=[L_obj,L_spat,L_verb]
plt.boxplot(box_plot_data,notch='True',labels=['Obj','Spat','Verb'])

plt.title('Lighting')
plt.ylim(1.5,5)
plt.show()     

box_plot_data=[C_obj,C_spat,C_verb]
plt.boxplot(box_plot_data,notch='True',labels=['Obj','Spat','Verb'])

plt.title('Construction')
plt.ylim(1.5,5)
plt.show() 

box_plot_data=[S_obj,S_spat,S_verb]
plt.boxplot(box_plot_data,notch='True',labels=['Obj','Spat','Verb'])

plt.title('Structural')
plt.ylim(1.5,5)
plt.show()     

box_plot_data=[M_obj,M_spat,M_verb]
plt.boxplot(box_plot_data,notch='True',labels=['Obj','Spat','Verb'])

plt.title('Mechanical')
plt.ylim(1.5,5)
plt.show()

# %%
# Kruskal-Wallis H-test
from numpy.random import seed
from numpy.random import randn
from scipy.stats import kruskal

# %%
# seed the random number generator
seed(1)

print('TESTING Mergability : 13-14-15-17')

# compare samples
stat, p = kruskal(L13_spat, L14_spat,L15_spat,L17_spat)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (LS =fail to reject H0)')
else:
    print('Different distributions (LS =reject H0)')


# seed the random number generator
seed(1)

# compare samples
stat, p = kruskal(L13_obj, L14_obj,L15_obj,L17_obj)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (LO= fail to reject H0)')
else:
    print('Different distributions (LO=reject H0)')

# seed the random number generator
seed(1)

# compare samples
stat, p = kruskal(L13_verb, L14_verb,L15_verb,L17_verb)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print('Same distributions (LV= fail to reject H0)')
else:
    print('Different distributions (LV= reject H0)')

# seed the random number generator
seed(1)

# compare samples
stat, p = kruskal(M13_spat, M14_spat,M15_spat,M17_spat)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (MS= fail to reject H0)')
else:
    print('Different distributions (MS=reject H0)')

# seed the random number generator
seed(1)

# compare samples
stat, p = kruskal(M13_obj, M14_obj,M15_obj,M17_obj)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print('Same distributions (MO= fail to reject H0)')
else:
    print('Different distributions (MO= reject H0)')
    
# seed the random number generator
seed(1)

# compare samples
stat, p = kruskal(M13_verb, M14_verb,M15_verb,M17_verb)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print('Same distributions (MV= fail to reject H0)')
else:
    print('Different distributions (MV= reject H0)')
    
# seed the random number generator
seed(1)

# compare samples
stat, p = kruskal(C13_spat, C14_spat,C15_spat,C17_spat)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (CS= fail to reject H0)')
else:
    print('Different distributions (CS=reject H0)')

# seed the random number generator
seed(1)

# compare samples
stat, p = kruskal(C13_obj, C14_obj,C15_obj,C17_obj)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print('Same distributions (CO= fail to reject H0)')
else:
    print('Different distributions (CO= reject H0)')
    
# seed the random number generator
seed(1)

# compare samples
stat, p = kruskal(C13_verb, C14_verb,C15_verb,C17_verb)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print('Same distributions (CV= fail to reject H0)')
else:
    print('Different distributions (CV= reject H0)')
    
# seed the random number generator
seed(1)

# compare samples
stat, p = kruskal(S13_spat, S14_spat,S15_spat,S17_spat)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (SS= fail to reject H0)')
else:
    print('Different distributions (SS=reject H0)')

# seed the random number generator
seed(1)

# compare samples
stat, p = kruskal(S13_obj, S14_obj,S15_obj,S17_obj)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print('Same distributions (SO= fail to reject H0)')
else:
    print('Different distributions (SO= reject H0)')
    
# seed the random number generator
seed(1)

# compare samples
stat, p = kruskal(S13_verb, S14_verb,S15_verb,S17_verb)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print('Same distributions (SV= fail to reject H0)')
else:
    print('Different distributions (SV= reject H0)')
# Out:
# TESTING Mergability : 13-14-15-17
# Statistics=3.996, p=0.262
#  Same distributions (LS =fail to reject H0)
# Statistics=5.968, p=0.113
#  Same distributions (LO= fail to reject H0)
# Statistics=1.015, p=0.798
# Same distributions (LV= fail to reject H0)
# Statistics=9.960, p=0.019
# Different distributions (MS=reject H0)
# Statistics=2.609, p=0.456
# Same distributions (MO= fail to reject H0)
# Statistics=2.929, p=0.403
# Same distributions (MV= fail to reject H0)
# Statistics=8.227, p=0.042
# Different distributions (CS=reject H0)
# Statistics=1.425, p=0.700
# Same distributions (CO= fail to reject H0)
# Statistics=1.232, p=0.745
# Same distributions (CV= fail to reject H0)
# Statistics=4.350, p=0.226
#  Same distributions (SS= fail to reject H0)
# Statistics=6.149, p=0.105
# Same distributions (SO= fail to reject H0)
# Statistics=2.153, p=0.541
# Same distributions (SV= fail to reject H0)

# %%
# seed the random number generator
seed(1)

print('Merged: Distribution of OSV in LCSM career')

# compare samples
stat, p = kruskal(L_spat,L_obj,L_verb)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (L=fail to reject H0)')
else:
    print('Different distributions (L =reject H0)')


# seed the random number generator
seed(1)

# compare samples
stat, p = kruskal(M_spat,M_obj,M_verb)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (M= fail to reject H0)')
else:
    print('Different distributions (M=reject H0)')

    
# seed the random number generator
seed(1)

# compare samples
stat, p = kruskal(C_spat,C_obj,C_verb)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (C= fail to reject H0)')
else:
    print('Different distributions (C=reject H0)')

# seed the random number generator
seed(1)

# compare samples
stat, p = kruskal(S_spat,S_obj,S_verb)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (S= fail to reject H0)')
else:
    print('Different distributions (S=reject H0)')
# Out:
# Merged: Distribution of OSV in LCSM career
# Statistics=70.522, p=0.000
# Different distributions (L =reject H0)
# Statistics=66.334, p=0.000
# Different distributions (M=reject H0)
# Statistics=129.403, p=0.000
# Different distributions (C=reject H0)
# Statistics=83.055, p=0.000
# Different distributions (S=reject H0)

# %%
# seed the random number generator
seed(1)

print('Merged: Distribution of LMCS in OSV styles')

# compare samples
stat, p = kruskal(M_obj,L_obj,C_obj,S_obj)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (Obj=fail to reject H0)')
else:
    print('Different distributions (obj =reject H0)')


# seed the random number generator
seed(1)

# compare samples
stat, p = kruskal(M_spat,L_spat,C_spat,S_spat)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (spat= fail to reject H0)')
else:
    print('Different distributions (spat=reject H0)')

    
# seed the random number generator
seed(1)

# compare samples
stat, p = kruskal(M_verb,L_verb,C_verb,S_verb)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (verb= fail to reject H0)')
else:
    print('Different distributions (verb =reject H0)')
# Out:
# Merged: Distribution of LMCS in OSV styles
# Statistics=8.530, p=0.036
# Different distributions (obj =reject H0)
# Statistics=7.501, p=0.058
#  Same distributions (spat= fail to reject H0)
# Statistics=4.490, p=0.213
#  Same distributions (verb= fail to reject H0)

# %%
# Mann-Whitney U test
from numpy.random import seed
from numpy.random import randn
from scipy.stats import mannwhitneyu

# %%
# seed the random number generator
seed(1)

print('Yearly Mechanical Spatial')

# compare samples
stat, p = mannwhitneyu(M13_spat, M14_spat)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (MS34= fail to reject H0)')
else:
    print('Different distributions (MS34=reject H0)')

# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(M15_spat,M17_spat)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print('Same distributions (MS57= fail to reject H0)')
else:
    print('Different distributions (MS57= reject H0)')
    
# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(M13_spat, M15_spat)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print('Same distributions (MS35= fail to reject H0)')
else:
    print('Different distributions (MS35= reject H0)')
    
# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(M13_spat, M17_spat)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (MS37= fail to reject H0)')
else:
    print('Different distributions (MS37=reject H0)')

# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(M14_spat, M15_spat)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print('Same distributions (MS45= fail to reject H0)')
else:
    print('Different distributions (MS45= reject H0)')
    
# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(M14_spat, M17_spat)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print('Same distributions (MS47= fail to reject H0)')
else:
    print('Different distributions (MS47= reject H0)')
# Out:
# Yearly Mechanical Spatial
# Statistics=64.000, p=0.014
# Different distributions (MS34=reject H0)
# Statistics=90.500, p=0.051
# Same distributions (MS57= fail to reject H0)
# Statistics=156.500, p=0.321
# Same distributions (MS35= fail to reject H0)
# Statistics=71.500, p=0.189
#  Same distributions (MS37= fail to reject H0)
# Statistics=117.000, p=0.029
# Different distributions (MS45= reject H0)
# Statistics=35.000, p=0.002
# Different distributions (MS47= reject H0)

# %%
# seed the random number generator
seed(1)

print('Yearly Construction Spatial')

# compare samples
stat, p = mannwhitneyu(C13_spat, C14_spat)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (CS34= fail to reject H0)')
else:
    print('Different distributions (CS34=reject H0)')

# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(C15_spat,C17_spat)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print('Same distributions (CS57= fail to reject H0)')
else:
    print('Different distributions (CS57= reject H0)')
    
# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(C13_spat, C15_spat)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print('Same distributions (CS35= fail to reject H0)')
else:
    print('Different distributions (CS35= reject H0)')
    
# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(C13_spat, C17_spat)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (CS37= fail to reject H0)')
else:
    print('Different distributions (CS37=reject H0)')

# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(C14_spat, C15_spat)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print('Same distributions (CS45= fail to reject H0)')
else:
    print('Different distributions (CS45= reject H0)')
    
# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(C14_spat, C17_spat)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print('Same distributions (CS47= fail to reject H0)')
else:
    print('Different distributions (CS47= reject H0)')
# Out:
# Yearly Construction Spatial
# Statistics=447.500, p=0.419
#  Same distributions (CS34= fail to reject H0)
# Statistics=170.500, p=0.007
# Different distributions (CS57= reject H0)
# Statistics=402.000, p=0.316
# Same distributions (CS35= fail to reject H0)
# Statistics=152.500, p=0.007
# Different distributions (CS37=reject H0)
# Statistics=482.500, p=0.351
# Same distributions (CS45= fail to reject H0)
# Statistics=190.000, p=0.010
# Different distributions (CS47= reject H0)

# %%
# seed the random number generator
seed(1)

print('Yerly Structural Spatial')

# compare samples
stat, p = mannwhitneyu(S13_spat, S14_spat)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (SS34= fail to reject H0)')
else:
    print('Different distributions (SS34=reject H0)')

# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(S15_spat,S17_spat)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print('Same distributions (SS57= fail to reject H0)')
else:
    print('Different distributions (SS57= reject H0)')
    
# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(S13_spat, S15_spat)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print('Same distributions (SS35= fail to reject H0)')
else:
    print('Different distributions (SS35= reject H0)')
    
# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(S13_spat, S17_spat)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (SS37= fail to reject H0)')
else:
    print('Different distributions (SS37=reject H0)')

# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(S14_spat, S15_spat)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print('Same distributions (SS45= fail to reject H0)')
else:
    print('Different distributions (SS45= reject H0)')
    
# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(S14_spat, S17_spat)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print('Same distributions (SS47= fail to reject H0)')
else:
    print('Different distributions (SS47= reject H0)')
# Out:
# Yerly Structural Spatial
# Statistics=129.500, p=0.169
#  Same distributions (SS34= fail to reject H0)
# Statistics=86.500, p=0.101
# Same distributions (SS57= fail to reject H0)
# Statistics=95.000, p=0.246
# Same distributions (SS35= fail to reject H0)
# Statistics=80.000, p=0.023
# Different distributions (SS37=reject H0)
# Statistics=138.500, p=0.486
# Same distributions (SS45= fail to reject H0)
# Statistics=131.000, p=0.120
# Same distributions (SS47= fail to reject H0)

# %%
# seed the random number generator
seed(1)

print('Yearly Lighting Spatial')

# compare samples
stat, p = mannwhitneyu(L13_spat, L14_spat)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (LS34= fail to reject H0)')
else:
    print('Different distributions (LS34=reject H0)')

# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(L15_spat,L17_spat)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print('Same distributions (LS57= fail to reject H0)')
else:
    print('Different distributions (LS57= reject H0)')
    
# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(L13_spat, L15_spat)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print('Same distributions (LS35= fail to reject H0)')
else:
    print('Different distributions (LS35= reject H0)')
    
# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(L13_spat, L17_spat)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (LS37= fail to reject H0)')
else:
    print('Different distributions (LS37=reject H0)')

# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(L14_spat, L15_spat)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print('Same distributions (LS45= fail to reject H0)')
else:
    print('Different distributions (LS45= reject H0)')
    
# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(L14_spat, L17_spat)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print('Same distributions (LS47= fail to reject H0)')
else:
    print('Different distributions (LS47= reject H0)')
# Out:
# Yearly Lighting Spatial
# Statistics=95.000, p=0.386
#  Same distributions (LS34= fail to reject H0)
# Statistics=69.500, p=0.455
# Same distributions (LS57= fail to reject H0)
# Statistics=70.500, p=0.122
# Same distributions (LS35= fail to reject H0)
# Statistics=38.500, p=0.142
#  Same distributions (LS37= fail to reject H0)
# Statistics=89.000, p=0.047
# Different distributions (LS45= reject H0)
# Statistics=51.000, p=0.088
# Same distributions (LS47= fail to reject H0)

# %%
# seed the random number generator
seed(1)

print('Merged: distribution of OSV in Lighting')

# compare sample
stat, p = mannwhitneyu(L_spat,L_obj)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (L- SO =fail to reject H0)')
else:
    print('Different distributions (L-SO =reject H0)')


# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu (L_spat,L_verb)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (L-SV= fail to reject H0)')
else:
    print('Different distributions (L-SV =reject H0)')

    
# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(L_obj,L_verb)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (L- OV= fail to reject H0)')
else:
    print('Different distributions (L-OV =reject H0)')
# Out:
# Merged: distribution of OSV in Lighting
# Statistics=1451.000, p=0.484
#  Same distributions (L- SO =fail to reject H0)
# Statistics=267.000, p=0.000
# Different distributions (L-SV =reject H0)
# Statistics=288.000, p=0.000
# Different distributions (L-OV =reject H0)

# %%
# seed the random number generator
seed(1)

print('Merged: distribution of OSV in Mech.')

# compare sample
stat, p = mannwhitneyu(M_spat,M_obj)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (M- SO =fail to reject H0)')
else:
    print('Different distributions (M-SO =reject H0)')


# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu (M_spat,M_verb)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (M -SV= fail to reject H0)')
else:
    print('Different distributions (M-SV =reject H0)')

    
# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu (M_obj,M_verb)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (M- OV= fail to reject H0)')
else:
    print('Different distributions (M-OV =reject H0)')
# Out:
# Merged: distribution of OSV in Mech.
# Statistics=790.500, p=0.001
# Different distributions (M-SO =reject H0)
# Statistics=153.500, p=0.000
# Different distributions (M-SV =reject H0)
# Statistics=424.000, p=0.000
# Different distributions (M-OV =reject H0)

# %%
# seed the random number generator
seed(1)

print('Merged: distribution of OSV in Structural')

# compare sample
stat, p = mannwhitneyu(S_spat,S_obj)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (S- SO =fail to reject H0)')
else:
    print('Different distributions (S-SO =reject H0)')


# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu (S_spat,S_verb)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (S-SV= fail to reject H0)')
else:
    print('Different distributions (S-SV =reject H0)')

    
# seed the random number generator
seed(1)

# compare samples
stat, p =mannwhitneyu (S_obj,S_verb)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (S- OV= fail to reject H0)')
else:
    print('Different distributions (S-OV =reject H0)')
# Out:
# Merged: distribution of OSV in Structural
# Statistics=1194.000, p=0.000
# Different distributions (S-SO =reject H0)
# Statistics=324.500, p=0.000
# Different distributions (S-SV =reject H0)
# Statistics=1011.500, p=0.000
# Different distributions (S-OV =reject H0)

# %%
# seed the random number generator
seed(1)

print('Merged: distribution of OSV in Constrution')

# compare sample
stat, p = mannwhitneyu(C_spat,C_obj)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (C- SO =fail to reject H0)')
else:
    print('Different distributions (C-SO =reject H0)')


# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu (C_spat,C_verb)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (C-SV= fail to reject H0)')
else:
    print('Different distributions (C-SV =reject H0)')

    
# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(C_obj,C_verb)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (C- OV= fail to reject H0)')
else:
    print('Different distributions (C-OV =reject H0)')
# Out:
# Merged: distribution of OSV in Constrution
# Statistics=2162.000, p=0.000
# Different distributions (C-SO =reject H0)
# Statistics=467.500, p=0.000
# Different distributions (C-SV =reject H0)
# Statistics=1568.500, p=0.000
# Different distributions (C-OV =reject H0)

# %%
# seed the random number generator
seed(1)

print('Merged: distribution of LMCS in Object')

# compare samples
stat, p = mannwhitneyu(L_obj,M_obj)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (LM Obj=fail to reject H0)')
else:
    print('Different distributions (LM Obj =reject H0)')


# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(L_obj,C_obj)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (LC Obj= fail to reject H0)')
else:
    print('Different distributions (LC Obj =reject H0)')

    
# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(L_obj,S_obj)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (LS Obj= fail to reject H0)')
else:
    print('Different distributions (LS Obj=reject H0)')
# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(S_obj,C_obj)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (SC Obj= fail to reject H0)')
else:
    print('Different distributions (SC Obj=reject H0)')

    
# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(S_obj,M_obj)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (SM Obj= fail to reject H0)')
else:
    print('Different distributions (SM Obj =reject H0)')
# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(M_obj,C_obj)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (MC Obj= fail to reject H0)')
else:
    print('Different distributions (MC Obj=reject H0)')
# Out:
# Merged: distribution of LMCS in Object
# Statistics=1038.500, p=0.021
# Different distributions (LM Obj =reject H0)
# Statistics=1785.000, p=0.002
# Different distributions (LC Obj =reject H0)
# Statistics=1369.000, p=0.011
# Different distributions (LS Obj=reject H0)
# Statistics=3035.500, p=0.436
#  Same distributions (SC Obj= fail to reject H0)
# Statistics=1649.000, p=0.444
#  Same distributions (SM Obj= fail to reject H0)
# Statistics=2276.500, p=0.461
#  Same distributions (MC Obj= fail to reject H0)

# %%
# seed the random number generator
seed(1)

print('Merged: distribution of LMCS in Spatial')

# compare samples
stat, p = mannwhitneyu(L_spat,M_spat)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (LM spat=fail to reject H0)')
else:
    print('Different distributions (LM spat =reject H0)')


# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(L_spat,C_spat)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (LC spat= fail to reject H0)')
else:
    print('Different distributions (LC spat =reject H0)')

    
# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(L_spat,S_spat)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (LS spat= fail to reject H0)')
else:
    print('Different distributions (LS spat=reject H0)')
# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(S_spat,C_spat)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (SC spat= fail to reject H0)')
else:
    print('Different distributions (SC spat=reject H0)')

    
# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(S_spat,M_spat)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (SM spat= fail to reject H0)')
else:
    print('Different distributions (SM spat =reject H0)')
# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(M_obj,C_obj)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (MC spat= fail to reject H0)')
else:
    print('Different distributions (MC spat=reject H0)')
# Out:
# Merged: distribution of LMCS in Spatial
# Statistics=1132.000, p=0.078
#  Same distributions (LM spat=fail to reject H0)
# Statistics=1925.000, p=0.012
# Different distributions (LC spat =reject H0)
# Statistics=1332.000, p=0.006
# Different distributions (LS spat=reject H0)
# Statistics=2888.500, p=0.250
#  Same distributions (SC spat= fail to reject H0)
# Statistics=1485.000, p=0.148
#  Same distributions (SM spat= fail to reject H0)
# Statistics=2276.500, p=0.461
#  Same distributions (MC spat= fail to reject H0)

# %%
# seed the random number generator
seed(1)

print('Merged: distribution of LMCS in Verbal')

# compare samples
stat, p = mannwhitneyu(L_verb,M_verb)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (LM verb=fail to reject H0)')
else:
    print('Different distributions (LM verb =reject H0)')


# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(L_verb,C_verb)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (LC verb= fail to reject H0)')
else:
    print('Different distributions (LC verb =reject H0)')

    
# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(L_verb,S_verb)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (LSverb= fail to reject H0)')
else:
    print('Different distributions (LS verb=reject H0)')
# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(S_verb,C_verb)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (SC verb= fail to reject H0)')
else:
    print('Different distributions (SC verb=reject H0)')

    
# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(S_verb,M_verb)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (SM verb= fail to reject H0)')
else:
    print('Different distributions (SM verb =reject H0)')
# seed the random number generator
seed(1)

# compare samples
stat, p = mannwhitneyu(M_verb,C_verb)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print(' Same distributions (MC verb= fail to reject H0)')
else:
    print('Different distributions (MC verb=reject H0)')
# Out:
# Merged: distribution of LMCS in Verbal
# Statistics=1108.000, p=0.058
#  Same distributions (LM verb=fail to reject H0)
# Statistics=2425.000, p=0.406
#  Same distributions (LC verb= fail to reject H0)
# Statistics=1783.000, p=0.447
#  Same distributions (LSverb= fail to reject H0)
# Statistics=3027.500, p=0.425
#  Same distributions (SC verb= fail to reject H0)
# Statistics=1384.500, p=0.055
#  Same distributions (SM verb= fail to reject H0)
# Statistics=1818.000, p=0.020
# Different distributions (MC verb=reject H0)

# %%
box_plot_data=[M13_spat,M14_spat,M15_spat,M17_spat]
plt.boxplot(box_plot_data,notch='True',labels=['2013','2014','2015','2017'])

plt.title('Mechanical: Spatial')
plt.ylim(2,5)
plt.show()     

box_plot_data=[S13_spat,S14_spat,S15_spat,S17_spat]
plt.boxplot(box_plot_data,notch='True',labels=['2013','2014','2015','2017'])

plt.title('Structural: Spatial')
plt.ylim(2,5)
plt.show() 

box_plot_data=[L13_spat,L14_spat,L15_spat,L17_spat]
plt.boxplot(box_plot_data,notch='True',labels=['2013','2014','2015','2017'])

plt.title('Lighting: Spatial')
plt.ylim(2,5)
plt.show() 

box_plot_data=[C13_spat,C14_spat,C15_spat,C17_spat]
plt.boxplot(box_plot_data,notch='True',labels=['2013','2014','2015','2017'])

plt.title('Construction:Spatial')
plt.ylim(2,5)
plt.show()

# %%
spat13= df0['Spat']
spat14= df1['Spat']
spat15= df2['Spat']
spat17= df3['Spat']

spat13,spat14,spat15,spat17
# Out:
# (0     3.533333
#  1     3.000000
#  2     4.533333
#  3     3.933333
#  4     3.200000
#          ...
#  66    4.200000
#  67    3.866667
#  68    4.000000
#  69    3.933333
#  70    3.400000
#  Name: Spat, Length: 71, dtype: float64, 0     4.000000
#  1     4.000000
#  2     3.866667
#  3     4.133333
#  4     4.066667
#          ...
#  81    3.400000
#  82    3.600000
#  83    4.266667
#  84    3.400000
#  85    3.600000
#  Name: Spat, Length: 86, dtype: float64, 0     3.600000
#  1     3.533333
#  2     3.933333
#  3     3.533333
#  4     2.733333
#          ...
#  79    3.733333
#  80    3.200000
#  81    3.333333
#  82    3.066667
#  83    3.933333
#  Name: Spat, Length: 84, dtype: float64, 0     3.666667
#  1     2.933333
#  2     3.666667
#  3     3.266667
#  4     3.066667
#  5     3.733333
#  6     3.066667
#  7     3.933333
#  8     3.066667
#  9     3.533333
#  10    3.533333
#  11    4.200000
#  12    3.933333
#  13    3.400000
#  14    3.266667
#  15    4.000000
# ...

# %%
box_plot_data=[spat13,spat14,spat15,spat17]
plt.boxplot(box_plot_data,notch='True',labels=['2013','2014','2015','2017'])

plt.title('Spatial')
plt.ylim(2,5)
plt.show()
